# %%
# !pip install requests lxml

# %%
import requests
from lxml import html

# %%
url = 'https://violetperm.ru/catalog/'

response = requests.get(url)

tree = html.fromstring(response.content)

headers_xpath = '//h1/text() | //h2/text() | //h3/text() | //h4/text() | //h5/text() | //h6/text()'

text_xpath = '//text()[normalize-space()]'

headers = tree.xpath(headers_xpath)

text_elements = tree.xpath(text_xpath)

print("Заголовок:")
for header in headers:
    print(header.strip())

print("Текст:")
for text in text_elements:
    print(text.strip())
# Out:
# Заголовок:
# Пермь
# Пермь
# 8 марта
#
# Выпечка сладкая
#
# Выпечка сытная
#
# Десерты
#
# Книги
#
# Печенье
#
# Пироги сытные
#
# Пирожные
#
# Тарты
#
# Торты
#
# Хлеб
#
# Текст:
# if(!window.BX)window.BX={};if(!window.BX.message)window.BX.message=function(mess){if(typeof mess==='object'){for(let i in mess) {BX.message[i]=mess[i];} return true;}};
# (window.BX||top.BX).message({'pull_server_enabled':'N','pull_config_timestamp':'0','pull_guest_mode':'N','pull_guest_user_id':'0'});(window.BX||top.BX).message({'PULL_OLD_REVISION':'Для продолжения корректной работы с сайтом необходимо перезагрузить страницу.'});
# ...

# %%
response = requests.get(url)
tree = html.fromstring(response.content)

headers_xpath = '//h1/text() | //h2/text() | //h3/text() | //h4/text() | //h5/text() | //h6/text()'
headers = tree.xpath(headers_xpath)

visible_text_xpath = '//body//*[not(self::script) and not(self::style) and not(self::noscript)]/text()[normalize-space()]'
text_elements = tree.xpath(visible_text_xpath)

print("Заголовки (очищенные):")
unique_headers = []
for header in headers:
    cleaned = header.strip()
    if cleaned and cleaned not in unique_headers:
        unique_headers.append(cleaned)
        print(cleaned)

print("\nТекст страницы (очищенный):")
unique_text = []
for text in text_elements:
    cleaned = text.strip()
    if (len(cleaned) > 1 and
        not cleaned.startswith(('var ', 'function', 'BX.', '$(', 'if(', 'new ', 'ym(')) and
        not cleaned.startswith(('/bitrix/', '{"', '//')) and
        cleaned not in unique_text):
        unique_text.append(cleaned)
        print(cleaned)
# Out:
# Заголовки (очищенные):
# Пермь
# 8 марта
# Выпечка сладкая
# Выпечка сытная
# Десерты
# Книги
# Печенье
# Пироги сытные
# Пирожные
# Тарты
# Торты
# Хлеб
#
# Текст страницы (очищенный):
# Виолет
# Каталог
# Доставка и оплата
# Контакты
# О нас
# +7 (912) 599-98-39
# Пермь
# Корзина
# Обратный звонок
# Наша команда
# Это люди, которые любят свое дело и вкладывают в него душу и тепло
# Традиции
# Мы соблюдаем традиции и идем в ногу со временем, открывая что-то новое и интересное
# Кондитерская
# Которая дарит людям праздник, витамины счастья и волшебную атмосферу
# Качество
# Мы следуем принципам – качество, доброжелательность, творчество
# Меню
# 8 марта
# Выпечка сладкая
# Выпечка сытная
# Десерты
# Книги
# Печенье
# Пироги сытные
# Пирожные
# Тарты
# Торты
# Хлеб
# Главная
# (11)
# (4)
# (6)
# (1)
# (3)
# (5)
# (36)
# (21)
# Подписывайтесь
# на новости и акции
# Я принимаю условия пользовательского соглашения
# © 2026 Виолет ИП Созинова О.Н.
# — Разработка сайта
# Заказать звонок
# ...
